# %% [markdown]
# # Task:
# -------

# %% [markdown]
# Q1. To Write the Python Code for below Output Using If, Elif, Else
# ------------------------------------------------------------------
#
#
# OutPut 01:
# ----------
#
# Enter Your Name: Sara
#
# Enter Your Age: 24
#
# Enter Your Mobile: 9500912258
#
# Hi Sara your are age is 24. So You are Eligible for Vote. And your Mobile is 9500912258
#
# OutPut 02:
# ----------
#
# Enter Your Name: Lara
#
# Enter Your Age: 12
#
# Enter Your Mobile: 950091
#
# Hi Lara your are age is 12. So You are Not Eligible for Vote. And your Mobile is InValid

# %% [markdown]
# Q2. To Write the Python Code for below Output Using Loop
# --------------------------------------------------------
#
# OutPut:
# -------
#
# A
#
# A B
#
# A B C
#
# A B C D
#
# A B C D E

# %% [markdown]
# Q3. To Write the Python Code for below Output Using Function
# ------------------------------------------------------------
#
# Call the Function
#
# simpleIntrest(1000, 2, 10)
#
# OutPut:
# -------
#
# Principle Amount is 1000
#
# Number of Year is 2
#
# Rate of Intrest is 10
#
# Simple Intrest is 200
