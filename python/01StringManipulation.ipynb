# %% [markdown]
# # String
# --------

# %%
name = 'Sara'

college = "st josph's"

para = '''
Python is an interpreted, object-oriented, high-level programming language known for its clear and readable syntax.
Its design philosophy emphasizes code readability through the use of significant indentation,
which makes the language easy to learn for beginners
'''

para02 = "Python is an interpreted, object-oriented, high-level programming language known for its clear and readable syntax. \n Its design philosophy emphasizes code readability through the use of significant indentation, \n which makes the language easy to learn for beginners"

print(name)
print(college)

print(para)

print(para02)
# Out:
# Sara
# st josph's
#
# Python is an interpreted, object-oriented, high-level programming language known for its clear and readable syntax.
# Its design philosophy emphasizes code readability through the use of significant indentation,
# which makes the language easy to learn for beginners
#
# Python is an interpreted, object-oriented, high-level programming language known for its clear and readable syntax.
#  Its design philosophy emphasizes code readability through the use of significant indentation,
#  which makes the language easy to learn for beginners

# %% [markdown]
# # String Manipulation
# ---------------------

# %%
gmail = 'sara@gmail.com - 01'

print(gmail, type(gmail))
# Out:
# sara@gmail.com - 01 <class 'str'>

# %%
print(len(gmail))
# Out:
# 19

# %%
print(gmail[0:3 + 1])
# Out:
# sara

# %%
print(gmail[5:10])
# Out:
# gmail

# %%
print(gmail[-19:-16 +1])
# Out:
# sara

# %% [markdown]
# String Function
# ---------------

# %%
name = 'SARA'

print(name.isupper())
# Out:
# True

# %%
name = 'sara'

print(name.islower())
# Out:
# False

# %%
name = 'Sara007'

print(name.isalpha())
# Out:
# False

# %%
name = 'Sara007'

print(name.isalnum())
# Out:
# True
